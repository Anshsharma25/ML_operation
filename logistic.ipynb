# %%
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression 
X,y = make_classification(n_samples = 1000, n_features = 10 , n_informative = 5 , n_redundant=5, n_classes = 2, random_state = 1)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train, y_test = train_test_split(X,y, test_size = 0.20 ,random_state =1)

# %%
from sklearn.model_selection import GridSearchCV
params = {'penalty' :('l1','l2','elasticnet'),'C':[1,2,3,4,5,10,20,30,40]}

classifer = LogisticRegression()

# %%
clf = GridSearchCV(classifer, param_grid=params ,cv = 5 ,verbose = 3)

# %%
clf
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [1, 2, 3, 4, 5, 10, 20, 30, 40],
#                          'penalty': ('l1', 'l2', 'elasticnet')},
#              verbose=3)

# %%
clf.fit(X_train ,y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END .....................C=1, penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END .....................C=1, penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END .....................C=1, penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END .....................C=1, penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END .....................C=1, penalty=l1;, score=nan total time=   0.0s
# [CV 1/5] END ...................C=1, penalty=l2;, score=0.856 total time=   0.0s
# [CV 2/5] END ...................C=1, penalty=l2;, score=0.762 total time=   0.0s
# [CV 3/5] END ...................C=1, penalty=l2;, score=0.806 total time=   0.0s
# [CV 4/5] END ...................C=1, penalty=l2;, score=0.806 total time=   0.0s
# [CV 5/5] END ...................C=1, penalty=l2;, score=0.800 total time=   0.0s
# [CV 1/5] END .............C=1, penalty=elasticnet;, score=nan total time=   0.0s
# ...

# %%
clf.best_score_
# Out:
# 0.80625

# %%
clf.best_params_
# Out:
# {'C': 1, 'penalty': 'l2'}

# %%
LogisticRegression(C= 1, penalty = 'l2')
# Out:
# LogisticRegression(C=1)

# %% [markdown]
# randomized cv

# %%
from sklearn.model_selection import RandomizedCV
clf = RandomizedCV(classifer, param_grid=params ,cv = 5 ,verbose = 3)
clf.fit(X_train ,y_train)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from sklearn.model_selection import RandomizedCV
#       2 clf = RandomizedCV(classifer, param_grid=params ,cv = 5 ,verbose = 3)
#       3 clf.fit(X_train ,y_train)
#
# ImportError: cannot import name 'RandomizedCV' from 'sklearn.model_selection' (C:\PYTHON311\Lib\site-packages\sklearn\model_selection\__init__.py)

# %%
sklearn.model_selection.RandomizedSearchCV(estimator, param_distributions, *, n_iter=10, scoring=None, n_jobs=None, refit=True, cv=None, verbose=0, pre_dispatch='2*n_jobs', random_state=None, error_score=nan, return_train_score=False)
# Out:
#   Cell In[14], line 1
#     sklearn.model_selection.RandomizedSearchCV(estimator, param_distributions, *, n_iter=10, scoring=None, n_jobs=None, refit=True, cv=None, verbose=0, pre_dispatch='2*n_jobs', random_state=None, error_score=nan, return_train_score=False)
#                                                ^
# SyntaxError: iterable argument unpacking follows keyword argument unpacking

# %% [raw]
# Data interpolation ?>> is a process of estimating data in a range , getting
# 1. Linear Interpolation
# 2. cubic Interpolation
# 3. Polynomial interpolation
#
# use case
# >> missig data , when we have lot of data missing
# >>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([1,2,3,4,5])
y = np.array([6,7,8,9,10])

# %%
plt.scatter(x,y)

# %%
x_new = np.linspace(1,5,10)
x_new
# Out:
# array([1.        , 1.44444444, 1.88888889, 2.33333333, 2.77777778,
#        3.22222222, 3.66666667, 4.11111111, 4.55555556, 5.        ])

# %%
y_interp = np.interp(x_new,x , y )

# %%
plt.scatter(x_new , y_interp)

# %%
# cubic interpoltaion

x = np.array([1,2,3,4,5])
y = np.array([1,8,27,64,125])
plt.scatter(x,y)

# %%
pip install scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.13.0-cp311-cp311-win_amd64.whl (46.2 MB)
#      -------------------------------------- 46.2/46.2 MB 849.6 kB/s eta 0:00:00
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\python311\lib\site-packages (from scipy) (1.24.3)
# Installing collected packages: scipy
# Successfully installed scipy-1.13.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 24.0
# [notice] To update, run: C:\PYTHON311\python.exe -m pip install --upgrade pip

# %%
from scipy.interpolate import interp1d

# %%
f = interp1d(x,y, kind = 'cubic')

# %%
f

# %%
x_new = np.linspace(1,5,10)
y_interp = f(x_new)

# %%
plt.scatter(x_new ,y_interp )

# %%
# polynomial inter

x = np.array([1,2,3,4,5])
y = np.array([1,4,9,1,25])
plt.scatter(x,y)

# %%
p = np.polyfit(x,y , 2)

# %%
x_new = np.linspace(1,5,10)
y_interp = np.polyval(p,x_new)

# %%
plt.scatter(x_new , y_interp)
